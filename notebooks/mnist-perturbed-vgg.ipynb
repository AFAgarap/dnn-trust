# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

__version__ = '1.0.0'

import matplotlib.pyplot as plt
from models.mini_vgg import MiniVGG
import numpy as np
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
import tensorflow as tf
from trustscore import TrustScore
from utils import plot_precision_curve
from utils import run_model
from utils import run_precision_plt
assert tf.__version__.startswith('2')

# %%
tf.config.experimental.set_memory_growth(
    tf.config.experimental.list_physical_devices('GPU')[0], True
)

# %%
tf.random.set_seed(42)
np.random.seed(42)

# %%
BATCH_SIZE = 512
EPOCHS = 60

# %%
(train_features, train_labels), (test_features, test_labels) = tf.keras.datasets.mnist.load_data()

train_features = train_features.reshape(-1, 28, 28, 1)
train_features = train_features.astype('float32')
train_features = train_features / 255.
train_features = train_features + tf.random.normal(stddev=5e-2, shape=train_features.shape)

test_features = test_features.reshape(-1, 28, 28, 1)
test_features = test_features.astype('float32')
test_features = test_features / 255.

train_labels = tf.keras.utils.to_categorical(train_labels)
test_labels = tf.keras.utils.to_categorical(test_labels)

# %%
validation_features, test_features, validation_labels, test_labels = train_test_split(test_features, test_labels, test_size=0.50, stratify=test_labels)

# %%
pca = PCA(n_components=64)
enc_train_features = pca.fit_transform(train_features.numpy().reshape(-1, 784))
enc_test_features = pca.transform(test_features.reshape(-1, 784))

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((train_features, train_labels))
train_dataset = train_dataset.prefetch(BATCH_SIZE * 8)
train_dataset = train_dataset.shuffle(train_features.shape[0])
train_dataset = train_dataset.batch(BATCH_SIZE, True)

validation_dataset = tf.data.Dataset.from_tensor_slices((validation_features, validation_labels))
validation_dataset = validation_dataset.batch((BATCH_SIZE // 4))

test_dataset = tf.data.Dataset.from_tensor_slices((test_features, test_labels))
test_dataset = test_dataset.batch((BATCH_SIZE // 4))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0828 00:56:13.333621 140328298334016 deprecation.py:323] From /home/darth/tf2/lib/python3.6/site-packages/tensorflow/python/data/util/random_seed.py:58: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
model = MiniVGG(input_shape=(28, 28, 1), num_classes=10)

# %%
model.compile(loss=tf.losses.categorical_crossentropy,
              optimizer=tf.optimizers.Adam(learning_rate=1e-2),
              metrics=['accuracy'])

# %%
model(train_features[0].numpy().reshape(1, 28, 28, 1))
# Out:
# <tf.Tensor: id=357, shape=(1, 10), dtype=float32, numpy=
# array([[0.101857  , 0.09605391, 0.09384203, 0.09653359, 0.10316653,
#         0.09707863, 0.10697706, 0.0997374 , 0.09930702, 0.10544679]],
#       dtype=float32)>

# %%
model.summary()
# Out:
# Model: "mini_vgg"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              multiple                  320
# _________________________________________________________________
# conv2d_1 (Conv2D)            multiple                  9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) multiple                  0
# _________________________________________________________________
# conv2d_2 (Conv2D)            multiple                  18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            multiple                  36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 multiple                  0
# _________________________________________________________________
# dropout (Dropout)            multiple                  0
# _________________________________________________________________
# flatten (Flatten)            multiple                  0
# _________________________________________________________________
# dense (Dense)                multiple                  262400
# _________________________________________________________________
# dropout_1 (Dropout)          multiple                  0
# _________________________________________________________________
# dense_1 (Dense)              multiple                  2570
# =================================================================
# Total params: 329,962
# Trainable params: 329,962
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(train_dataset,
                    epochs=60,
                    validation_data=validation_dataset,
                    verbose=2)
# Out:
# Epoch 1/60
# 117/117 - 10s - loss: 0.4320 - accuracy: 0.6629 - val_loss: 0.0726 - val_accuracy: 0.9762
# Epoch 2/60
# 117/117 - 8s - loss: 0.0679 - accuracy: 0.9764 - val_loss: 0.0419 - val_accuracy: 0.9864
# Epoch 3/60
# 117/117 - 8s - loss: 0.0492 - accuracy: 0.9843 - val_loss: 0.0399 - val_accuracy: 0.9880
# Epoch 4/60
# 117/117 - 8s - loss: 0.0388 - accuracy: 0.9874 - val_loss: 0.0417 - val_accuracy: 0.9856
# Epoch 5/60
# 117/117 - 8s - loss: 0.0342 - accuracy: 0.9888 - val_loss: 0.0384 - val_accuracy: 0.9866
# Epoch 6/60
# 117/117 - 8s - loss: 0.0304 - accuracy: 0.9900 - val_loss: 0.0352 - val_accuracy: 0.9894
# Epoch 7/60
# 117/117 - 8s - loss: 0.0303 - accuracy: 0.9909 - val_loss: 0.0347 - val_accuracy: 0.9888
# Epoch 8/60
# 117/117 - 9s - loss: 0.0251 - accuracy: 0.9915 - val_loss: 0.0392 - val_accuracy: 0.9882
# Epoch 9/60
# 117/117 - 8s - loss: 0.0242 - accuracy: 0.9922 - val_loss: 0.0372 - val_accuracy: 0.9890
# Epoch 10/60
# 117/117 - 8s - loss: 0.0229 - accuracy: 0.9924 - val_loss: 0.0332 - val_accuracy: 0.9898
# Epoch 11/60
# 117/117 - 8s - loss: 0.0200 - accuracy: 0.9939 - val_loss: 0.0447 - val_accuracy: 0.9886
# Epoch 12/60
# 117/117 - 8s - loss: 0.0215 - accuracy: 0.9932 - val_loss: 0.0398 - val_accuracy: 0.9886
# Epoch 13/60
# 117/117 - 8s - loss: 0.0221 - accuracy: 0.9937 - val_loss: 0.0427 - val_accuracy: 0.9878
# Epoch 14/60
# 117/117 - 8s - loss: 0.0208 - accuracy: 0.9925 - val_loss: 0.0385 - val_accuracy: 0.9884
# Epoch 15/60
# 117/117 - 9s - loss: 0.0180 - accuracy: 0.9946 - val_loss: 0.0629 - val_accuracy: 0.9868
# Epoch 16/60
# 117/117 - 8s - loss: 0.0205 - accuracy: 0.9925 - val_loss: 0.0387 - val_accuracy: 0.9890
# Epoch 17/60
# 117/117 - 8s - loss: 0.0189 - accuracy: 0.9940 - val_loss: 0.0363 - val_accuracy: 0.9900
# Epoch 18/60
# 117/117 - 8s - loss: 0.0147 - accuracy: 0.9952 - val_loss: 0.0520 - val_accuracy: 0.9888
# Epoch 19/60
# 117/117 - 8s - loss: 0.0165 - accuracy: 0.9946 - val_loss: 0.0566 - val_accuracy: 0.9858
# Epoch 20/60
# 117/117 - 8s - loss: 0.0193 - accuracy: 0.9926 - val_loss: 0.0348 - val_accuracy: 0.9906
# Epoch 21/60
# 117/117 - 8s - loss: 0.0145 - accuracy: 0.9956 - val_loss: 0.0593 - val_accuracy: 0.9868
# Epoch 22/60
# 117/117 - 8s - loss: 0.0169 - accuracy: 0.9947 - val_loss: 0.0498 - val_accuracy: 0.9880
# Epoch 23/60
# 117/117 - 8s - loss: 0.0184 - accuracy: 0.9951 - val_loss: 0.0583 - val_accuracy: 0.9860
# Epoch 24/60
# 117/117 - 8s - loss: 0.0179 - accuracy: 0.9947 - val_loss: 0.0497 - val_accuracy: 0.9862
# Epoch 25/60
# 117/117 - 9s - loss: 0.0152 - accuracy: 0.9950 - val_loss: 0.0476 - val_accuracy: 0.9896
# Epoch 26/60
# 117/117 - 8s - loss: 0.0171 - accuracy: 0.9954 - val_loss: 0.0601 - val_accuracy: 0.9862
# Epoch 27/60
# 117/117 - 8s - loss: 0.0191 - accuracy: 0.9941 - val_loss: 0.0454 - val_accuracy: 0.9890
# Epoch 28/60
# 117/117 - 8s - loss: 0.0174 - accuracy: 0.9946 - val_loss: 0.0518 - val_accuracy: 0.9888
# Epoch 29/60
# 117/117 - 8s - loss: 0.0217 - accuracy: 0.9941 - val_loss: 0.0505 - val_accuracy: 0.9864
# Epoch 30/60
# 117/117 - 8s - loss: 0.0138 - accuracy: 0.9950 - val_loss: 0.0448 - val_accuracy: 0.9888
# Epoch 31/60
# 117/117 - 8s - loss: 0.0152 - accuracy: 0.9961 - val_loss: 0.0464 - val_accuracy: 0.9882
# Epoch 32/60
# 117/117 - 8s - loss: 0.0135 - accuracy: 0.9958 - val_loss: 0.0497 - val_accuracy: 0.9896
# Epoch 33/60
# 117/117 - 8s - loss: 0.0166 - accuracy: 0.9950 - val_loss: 0.0445 - val_accuracy: 0.9908
# Epoch 34/60
# 117/117 - 8s - loss: 0.0167 - accuracy: 0.9953 - val_loss: 0.0511 - val_accuracy: 0.9868
# Epoch 35/60
# 117/117 - 8s - loss: 0.0170 - accuracy: 0.9945 - val_loss: 0.0442 - val_accuracy: 0.9904
# Epoch 36/60
# 117/117 - 8s - loss: 0.0100 - accuracy: 0.9968 - val_loss: 0.0565 - val_accuracy: 0.9892
# Epoch 37/60
# 117/117 - 8s - loss: 0.0148 - accuracy: 0.9964 - val_loss: 0.0489 - val_accuracy: 0.9910
# Epoch 38/60
# 117/117 - 8s - loss: 0.0134 - accuracy: 0.9966 - val_loss: 0.0467 - val_accuracy: 0.9888
# Epoch 39/60
# 117/117 - 8s - loss: 0.0151 - accuracy: 0.9959 - val_loss: 0.0564 - val_accuracy: 0.9896
# Epoch 40/60
# 117/117 - 8s - loss: 0.0226 - accuracy: 0.9945 - val_loss: 0.0567 - val_accuracy: 0.9878
# Epoch 41/60
# 117/117 - 8s - loss: 0.0203 - accuracy: 0.9952 - val_loss: 0.0413 - val_accuracy: 0.9896
# Epoch 42/60
# 117/117 - 8s - loss: 0.0210 - accuracy: 0.9940 - val_loss: 0.0545 - val_accuracy: 0.9888
# Epoch 43/60
# 117/117 - 8s - loss: 0.0160 - accuracy: 0.9959 - val_loss: 0.0576 - val_accuracy: 0.9896
# Epoch 44/60
# 117/117 - 8s - loss: 0.0155 - accuracy: 0.9962 - val_loss: 0.0777 - val_accuracy: 0.9870
# Epoch 45/60
# 117/117 - 8s - loss: 0.0152 - accuracy: 0.9957 - val_loss: 0.0610 - val_accuracy: 0.9876
# Epoch 46/60
# 117/117 - 8s - loss: 0.0163 - accuracy: 0.9957 - val_loss: 0.0670 - val_accuracy: 0.9876
# Epoch 47/60
# 117/117 - 8s - loss: 0.0179 - accuracy: 0.9959 - val_loss: 0.0863 - val_accuracy: 0.9862
# Epoch 48/60
# 117/117 - 8s - loss: 0.0195 - accuracy: 0.9944 - val_loss: 0.0730 - val_accuracy: 0.9872
# Epoch 49/60
# 117/117 - 8s - loss: 0.0191 - accuracy: 0.9947 - val_loss: 0.0636 - val_accuracy: 0.9870
# Epoch 50/60
# 117/117 - 8s - loss: 0.0302 - accuracy: 0.9935 - val_loss: 0.0834 - val_accuracy: 0.9846
# Epoch 51/60
# 117/117 - 8s - loss: 0.0243 - accuracy: 0.9938 - val_loss: 0.0785 - val_accuracy: 0.9870
# Epoch 52/60
# 117/117 - 9s - loss: 0.0214 - accuracy: 0.9949 - val_loss: 0.0710 - val_accuracy: 0.9884
# Epoch 53/60
# 117/117 - 8s - loss: 0.0150 - accuracy: 0.9956 - val_loss: 0.0685 - val_accuracy: 0.9878
# Epoch 54/60
# 117/117 - 8s - loss: 0.0179 - accuracy: 0.9953 - val_loss: 0.0833 - val_accuracy: 0.9870
# Epoch 55/60
# 117/117 - 8s - loss: 0.0094 - accuracy: 0.9969 - val_loss: 0.0650 - val_accuracy: 0.9892
# Epoch 56/60
# 117/117 - 8s - loss: 0.0126 - accuracy: 0.9975 - val_loss: 0.0791 - val_accuracy: 0.9868
# Epoch 57/60
# 117/117 - 8s - loss: 0.0197 - accuracy: 0.9957 - val_loss: 0.0966 - val_accuracy: 0.9864
# Epoch 58/60
# 117/117 - 8s - loss: 0.0200 - accuracy: 0.9950 - val_loss: 0.0871 - val_accuracy: 0.9884
# Epoch 59/60
# 117/117 - 8s - loss: 0.0307 - accuracy: 0.9944 - val_loss: 0.0734 - val_accuracy: 0.9850
# Epoch 60/60
# 117/117 - 8s - loss: 0.0260 - accuracy: 0.9923 - val_loss: 0.0730 - val_accuracy: 0.9880

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
score = model.evaluate(test_dataset)
print('test accuracy : {}'.format(score[1]))
# Out:
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0688 - accuracy: 0.9890
# test accuracy : 0.9890000224113464

# %%
ts = TrustScore(alpha=5e-2)
ts.fit(enc_train_features, train_labels)

# %%
predictions = model.predict(test_features)

# %%
trust_scores, closest_classes = ts.score(enc_test_features,
                                         predictions,
                                         k=5)

# %%
num_samples = 5
index_min = np.argsort(trust_scores)[:num_samples]
index_max = np.argsort(trust_scores)[-num_samples:]
score_min = trust_scores[index_min]
score_max = trust_scores[index_max]
closest_min = closest_classes[index_min]
closest_max = closest_classes[index_max]
prediction_min = tf.argmax(predictions[index_min], 1)
prediction_max = tf.argmax(predictions[index_max], 1)
likelihood_min = tf.math.reduce_max(predictions[index_min], 1)
likelihood_max = tf.math.reduce_max(predictions[index_max], 1)
label_min = tf.argmax(test_labels[index_min], 1)
label_max = tf.argmax(test_labels[index_max], 1)
features_min = test_features[index_min]
features_max = test_features[index_max]

# %%
plt.figure(figsize=(20, 4))

for index in range(num_samples):
    axis = plt.subplot(1, num_samples, index + 1)
    plt.imshow(features_min[index].reshape(28, 28), cmap='gray')
    plt.title('Model prediction : {} ({:.3f})\nLabel : {} \nTrust score : {:.3f}' \
              '\nClosest other class : {}'.format(prediction_min.numpy()[index],
                                                  likelihood_min[index],
                                                  label_min.numpy()[index],
                                                  score_min[index],
                                                  closest_min[index]))
    axis.get_xaxis().set_visible(False)
    axis.get_yaxis().set_visible(False)
plt.show()

# %%
plt.figure(figsize=(20, 4))

for index in range(num_samples):
    axis = plt.subplot(1, num_samples, index + 1)
    plt.imshow(features_max[index].reshape(28, 28), cmap='gray')
    plt.title('Model prediction : {} ({:.3f})\nLabel : {}\nTrust score : {:.3f}' \
              '\nClosest other class : {}'.format(prediction_max.numpy()[index],
                                                  likelihood_max[index],
                                                  label_max.numpy()[index],
                                                  score_max[index],
                                                  closest_max[index]))
    axis.get_xaxis().set_visible(False)
    axis.get_yaxis().set_visible(False)
plt.show()

# %%
model.save_weights('saved_model/mnist-perturbed/mini-vgg/1', save_format='tf')

# %%
percentiles = [0 + 0.5 * index for index in range(200)]
num_fold = 5
plt_names = ['Model Confidence', 'Trust Score']

# %%
run_precision_plt(train_features.numpy(),
                  train_labels,
                  num_fold,
                  percentiles,
                  run_model,
                  plt_title='',
                  plt_names=plt_names,
                  predict_correct=True,
                  model=model)
