# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

__version__ = '1.0.0'

import matplotlib.pyplot as plt
from models.dnn import NeuralNet
import numpy as np
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
import tensorflow as tf
from trustscore import TrustScore
from utils import plot_precision_curve
from utils import run_model
from utils import run_precision_plt
assert tf.__version__.startswith('2')

# %%
tf.config.experimental.set_memory_growth(
    tf.config.experimental.list_physical_devices('GPU')[0], True
)

# %%
tf.random.set_seed(42)
np.random.seed(42)

# %%
BATCH_SIZE = 512
EPOCHS = 60

# %%
(train_features, train_labels), (test_features, test_labels) = tf.keras.datasets.mnist.load_data()

train_features = train_features.reshape(-1, 784)
train_features = train_features.astype('float32')
train_features = train_features / 255.
train_features = train_features + tf.random.normal(stddev=5e-2, shape=train_features.shape)

test_features = test_features.reshape(-1, 784)
test_features = test_features.astype('float32')
test_features = test_features / 255.

train_labels = tf.keras.utils.to_categorical(train_labels)
test_labels = tf.keras.utils.to_categorical(test_labels)

# %%
validation_features, test_features, validation_labels, test_labels = train_test_split(test_features, test_labels, test_size=0.50, stratify=test_labels)

# %%
pca = PCA(n_components=64)
enc_train_features = pca.fit_transform(train_features)
enc_test_features = pca.transform(test_features)

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((train_features, train_labels))
train_dataset = train_dataset.prefetch(BATCH_SIZE * 8)
train_dataset = train_dataset.shuffle(train_features.shape[0])
train_dataset = train_dataset.batch(BATCH_SIZE, True)

validation_dataset = tf.data.Dataset.from_tensor_slices((validation_features, validation_labels))
validation_dataset = validation_dataset.batch((BATCH_SIZE // 4))

test_dataset = tf.data.Dataset.from_tensor_slices((test_features, test_labels))
test_dataset = test_dataset.batch((BATCH_SIZE // 4))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0828 00:40:13.259995 140434463545152 deprecation.py:323] From /home/darth/tf2/lib/python3.6/site-packages/tensorflow/python/data/util/random_seed.py:58: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
model = NeuralNet(input_shape=(784,),
                  units=[512, 512],
                  dropout_rate=2e-1,
                  num_classes=10)

# %%
model.compile(loss=tf.losses.categorical_crossentropy,
              optimizer=tf.optimizers.SGD(learning_rate=1e-1, decay=1e-6, momentum=9e-1),
              metrics=['accuracy'])

# %%
model(train_features[0].numpy().reshape(1, 784))
# Out:
# <tf.Tensor: id=202, shape=(1, 10), dtype=float32, numpy=
# array([[0.08402405, 0.11218117, 0.14662236, 0.14143477, 0.08804614,
#         0.06393152, 0.07061312, 0.09396757, 0.10275241, 0.0964269 ]],
#       dtype=float32)>

# %%
model.summary()
# Out:
# Model: "neural_net"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                multiple                  401920
# _________________________________________________________________
# dropout (Dropout)            multiple                  0
# _________________________________________________________________
# dense_1 (Dense)              multiple                  262656
# _________________________________________________________________
# dropout_1 (Dropout)          multiple                  0
# _________________________________________________________________
# dense_2 (Dense)              multiple                  5130
# =================================================================
# Total params: 669,706
# Trainable params: 669,706
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(train_dataset,
                    epochs=60,
                    validation_data=validation_dataset,
                    verbose=2)
# Out:
# Epoch 1/60
# 117/117 - 3s - loss: 0.4086 - accuracy: 0.7733 - val_loss: 0.1620 - val_accuracy: 0.9510
# Epoch 2/60
# 117/117 - 2s - loss: 0.1315 - accuracy: 0.9571 - val_loss: 0.1081 - val_accuracy: 0.9658
# Epoch 3/60
# 117/117 - 2s - loss: 0.0871 - accuracy: 0.9726 - val_loss: 0.0904 - val_accuracy: 0.9718
# Epoch 4/60
# 117/117 - 2s - loss: 0.0631 - accuracy: 0.9814 - val_loss: 0.0811 - val_accuracy: 0.9750
# Epoch 5/60
# 117/117 - 2s - loss: 0.0486 - accuracy: 0.9860 - val_loss: 0.0760 - val_accuracy: 0.9746
# Epoch 6/60
# 117/117 - 2s - loss: 0.0396 - accuracy: 0.9883 - val_loss: 0.0726 - val_accuracy: 0.9760
# Epoch 7/60
# 117/117 - 2s - loss: 0.0317 - accuracy: 0.9907 - val_loss: 0.0646 - val_accuracy: 0.9802
# Epoch 8/60
# 117/117 - 2s - loss: 0.0245 - accuracy: 0.9934 - val_loss: 0.0706 - val_accuracy: 0.9790
# Epoch 9/60
# 117/117 - 1s - loss: 0.0206 - accuracy: 0.9950 - val_loss: 0.0862 - val_accuracy: 0.9740
# Epoch 10/60
# 117/117 - 1s - loss: 0.0167 - accuracy: 0.9960 - val_loss: 0.1077 - val_accuracy: 0.9700
# Epoch 11/60
# 117/117 - 1s - loss: 0.0151 - accuracy: 0.9956 - val_loss: 0.0675 - val_accuracy: 0.9796
# Epoch 12/60
# 117/117 - 1s - loss: 0.0124 - accuracy: 0.9968 - val_loss: 0.0630 - val_accuracy: 0.9814
# Epoch 13/60
# 117/117 - 1s - loss: 0.0105 - accuracy: 0.9972 - val_loss: 0.0685 - val_accuracy: 0.9812
# Epoch 14/60
# 117/117 - 1s - loss: 0.0074 - accuracy: 0.9979 - val_loss: 0.0639 - val_accuracy: 0.9822
# Epoch 15/60
# 117/117 - 1s - loss: 0.0051 - accuracy: 0.9993 - val_loss: 0.0633 - val_accuracy: 0.9822
# Epoch 16/60
# 117/117 - 1s - loss: 0.0041 - accuracy: 0.9995 - val_loss: 0.0703 - val_accuracy: 0.9800
# Epoch 17/60
# 117/117 - 1s - loss: 0.0034 - accuracy: 0.9994 - val_loss: 0.0812 - val_accuracy: 0.9760
# Epoch 18/60
# 117/117 - 1s - loss: 0.0037 - accuracy: 0.9985 - val_loss: 0.0613 - val_accuracy: 0.9838
# Epoch 19/60
# 117/117 - 1s - loss: 0.0022 - accuracy: 0.9998 - val_loss: 0.0604 - val_accuracy: 0.9840
# Epoch 20/60
# 117/117 - 1s - loss: 0.0017 - accuracy: 0.9999 - val_loss: 0.0613 - val_accuracy: 0.9844
# Epoch 21/60
# 117/117 - 1s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0620 - val_accuracy: 0.9844
# Epoch 22/60
# 117/117 - 1s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0622 - val_accuracy: 0.9850
# Epoch 23/60
# 117/117 - 1s - loss: 9.8507e-04 - accuracy: 1.0000 - val_loss: 0.0627 - val_accuracy: 0.9848
# Epoch 24/60
# 117/117 - 1s - loss: 9.0920e-04 - accuracy: 1.0000 - val_loss: 0.0631 - val_accuracy: 0.9846
# Epoch 25/60
# 117/117 - 1s - loss: 8.5361e-04 - accuracy: 1.0000 - val_loss: 0.0634 - val_accuracy: 0.9846
# Epoch 26/60
# 117/117 - 1s - loss: 8.0948e-04 - accuracy: 1.0000 - val_loss: 0.0638 - val_accuracy: 0.9844
# Epoch 27/60
# 117/117 - 1s - loss: 7.7300e-04 - accuracy: 1.0000 - val_loss: 0.0640 - val_accuracy: 0.9842
# Epoch 28/60
# 117/117 - 1s - loss: 7.4155e-04 - accuracy: 1.0000 - val_loss: 0.0643 - val_accuracy: 0.9842
# Epoch 29/60
# 117/117 - 1s - loss: 7.1420e-04 - accuracy: 1.0000 - val_loss: 0.0645 - val_accuracy: 0.9842
# Epoch 30/60
# 117/117 - 1s - loss: 6.9016e-04 - accuracy: 1.0000 - val_loss: 0.0647 - val_accuracy: 0.9840
# Epoch 31/60
# 117/117 - 1s - loss: 6.6833e-04 - accuracy: 1.0000 - val_loss: 0.0650 - val_accuracy: 0.9840
# Epoch 32/60
# 117/117 - 1s - loss: 6.4907e-04 - accuracy: 1.0000 - val_loss: 0.0652 - val_accuracy: 0.9840
# Epoch 33/60
# 117/117 - 1s - loss: 6.3147e-04 - accuracy: 1.0000 - val_loss: 0.0654 - val_accuracy: 0.9840
# Epoch 34/60
# 117/117 - 1s - loss: 6.1538e-04 - accuracy: 1.0000 - val_loss: 0.0655 - val_accuracy: 0.9840
# Epoch 35/60
# 117/117 - 1s - loss: 6.0080e-04 - accuracy: 1.0000 - val_loss: 0.0657 - val_accuracy: 0.9840
# Epoch 36/60
# 117/117 - 1s - loss: 5.8732e-04 - accuracy: 1.0000 - val_loss: 0.0659 - val_accuracy: 0.9840
# Epoch 37/60
# 117/117 - 1s - loss: 5.7496e-04 - accuracy: 1.0000 - val_loss: 0.0660 - val_accuracy: 0.9842
# Epoch 38/60
# 117/117 - 1s - loss: 5.6342e-04 - accuracy: 1.0000 - val_loss: 0.0662 - val_accuracy: 0.9842
# Epoch 39/60
# 117/117 - 1s - loss: 5.5283e-04 - accuracy: 1.0000 - val_loss: 0.0664 - val_accuracy: 0.9842
# Epoch 40/60
# 117/117 - 1s - loss: 5.4286e-04 - accuracy: 1.0000 - val_loss: 0.0665 - val_accuracy: 0.9842
# Epoch 41/60
# 117/117 - 1s - loss: 5.3356e-04 - accuracy: 1.0000 - val_loss: 0.0667 - val_accuracy: 0.9842
# Epoch 42/60
# 117/117 - 1s - loss: 5.2496e-04 - accuracy: 1.0000 - val_loss: 0.0668 - val_accuracy: 0.9842
# Epoch 43/60
# 117/117 - 1s - loss: 5.1679e-04 - accuracy: 1.0000 - val_loss: 0.0670 - val_accuracy: 0.9842
# Epoch 44/60
# 117/117 - 1s - loss: 5.0914e-04 - accuracy: 1.0000 - val_loss: 0.0671 - val_accuracy: 0.9842
# Epoch 45/60
# 117/117 - 1s - loss: 5.0195e-04 - accuracy: 1.0000 - val_loss: 0.0672 - val_accuracy: 0.9840
# Epoch 46/60
# 117/117 - 1s - loss: 4.9516e-04 - accuracy: 1.0000 - val_loss: 0.0674 - val_accuracy: 0.9840
# Epoch 47/60
# 117/117 - 1s - loss: 4.8878e-04 - accuracy: 1.0000 - val_loss: 0.0675 - val_accuracy: 0.9840
# Epoch 48/60
# 117/117 - 1s - loss: 4.8266e-04 - accuracy: 1.0000 - val_loss: 0.0676 - val_accuracy: 0.9840
# Epoch 49/60
# 117/117 - 1s - loss: 4.7689e-04 - accuracy: 1.0000 - val_loss: 0.0677 - val_accuracy: 0.9840
# Epoch 50/60
# 117/117 - 1s - loss: 4.7144e-04 - accuracy: 1.0000 - val_loss: 0.0678 - val_accuracy: 0.9842
# Epoch 51/60
# 117/117 - 1s - loss: 4.6621e-04 - accuracy: 1.0000 - val_loss: 0.0679 - val_accuracy: 0.9842
# Epoch 52/60
# 117/117 - 1s - loss: 4.6129e-04 - accuracy: 1.0000 - val_loss: 0.0680 - val_accuracy: 0.9842
# Epoch 53/60
# 117/117 - 1s - loss: 4.5654e-04 - accuracy: 1.0000 - val_loss: 0.0681 - val_accuracy: 0.9842
# Epoch 54/60
# 117/117 - 1s - loss: 4.5206e-04 - accuracy: 1.0000 - val_loss: 0.0682 - val_accuracy: 0.9842
# Epoch 55/60
# 117/117 - 1s - loss: 4.4774e-04 - accuracy: 1.0000 - val_loss: 0.0683 - val_accuracy: 0.9842
# Epoch 56/60
# 117/117 - 1s - loss: 4.4362e-04 - accuracy: 1.0000 - val_loss: 0.0684 - val_accuracy: 0.9842
# Epoch 57/60
# 117/117 - 1s - loss: 4.3969e-04 - accuracy: 1.0000 - val_loss: 0.0685 - val_accuracy: 0.9842
# Epoch 58/60
# 117/117 - 1s - loss: 4.3592e-04 - accuracy: 1.0000 - val_loss: 0.0686 - val_accuracy: 0.9840
# Epoch 59/60
# 117/117 - 1s - loss: 4.3230e-04 - accuracy: 1.0000 - val_loss: 0.0687 - val_accuracy: 0.9840
# Epoch 60/60
# 117/117 - 1s - loss: 4.2881e-04 - accuracy: 1.0000 - val_loss: 0.0688 - val_accuracy: 0.9840

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
score = model.evaluate(test_dataset)
print('test accuracy : {}'.format(score[1]))
# Out:
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0691 - accuracy: 0.9828
# test accuracy : 0.9828000068664551

# %%
ts = TrustScore(alpha=5e-2)
ts.fit(enc_train_features, train_labels)

# %%
predictions = model.predict(test_features)

# %%
trust_scores, closest_classes = ts.score(enc_test_features,
                                         predictions,
                                         k=5)

# %%
num_samples = 5
index_min = np.argsort(trust_scores)[:num_samples]
index_max = np.argsort(trust_scores)[-num_samples:]
score_min = trust_scores[index_min]
score_max = trust_scores[index_max]
closest_min = closest_classes[index_min]
closest_max = closest_classes[index_max]
prediction_min = tf.argmax(predictions[index_min], 1)
prediction_max = tf.argmax(predictions[index_max], 1)
likelihood_min = tf.math.reduce_max(predictions[index_min], 1)
likelihood_max = tf.math.reduce_max(predictions[index_max], 1)
label_min = tf.argmax(test_labels[index_min], 1)
label_max = tf.argmax(test_labels[index_max], 1)
features_min = test_features[index_min]
features_max = test_features[index_max]

# %%
plt.figure(figsize=(20, 4))

for index in range(num_samples):
    axis = plt.subplot(1, num_samples, index + 1)
    plt.imshow(features_min[index].reshape(28, 28), cmap='gray')
    plt.title('Model prediction : {} ({:.3f})\nLabel : {}\nTrust score : {:.3f}' \
              '\nClosest other class : {}'.format(prediction_min.numpy()[index],
                                                  likelihood_min[index],
                                                  label_min.numpy()[index],
                                                  score_min[index],
                                                  closest_min[index]))
    axis.get_xaxis().set_visible(False)
    axis.get_yaxis().set_visible(False)
plt.show()

# %%
plt.figure(figsize=(20, 4))

for index in range(num_samples):
    axis = plt.subplot(1, num_samples, index + 1)
    plt.imshow(features_max[index].reshape(28, 28), cmap='gray')
    plt.title('Model prediction : {} ({:.3f})\nLabel : {}\nTrust score : {:.3f}' \
              '\nClosest other class : {}'.format(prediction_max.numpy()[index],
                                                  likelihood_max[index],
                                                  label_max.numpy()[index],
                                                  score_max[index],
                                                  closest_max[index]))
    axis.get_xaxis().set_visible(False)
    axis.get_yaxis().set_visible(False)
plt.show()

# %%
model.save_weights('saved_model/mnist-perturbed/dnn/1', save_format='tf')

# %%
percentiles = [0 + 0.5 * index for index in range(200)]
num_fold = 5
plt_names = ['Model Confidence', 'Trust Score']

# %%
run_precision_plt(train_features.numpy(),
                  train_labels,
                  num_fold,
                  percentiles,
                  run_model,
                  plt_title='',
                  plt_names=plt_names,
                  predict_correct=True,
                  model=model)
